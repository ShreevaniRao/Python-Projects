# %%
# Find Top 100 Movies with highest Ratings using Requests, BeautifulSoup & Pandas libraries

# %%
# Import necessary modules
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Set the URL to scrape
url = "https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc"

# %%
# Send an HTTP request to the URL and store the response
response = requests.get(url)

# %%
# Parse the HTML content of the response
soup = BeautifulSoup(response.content, "html.parser")

# %%
# Find all the <div> elements with the class "lister-item mode-advanced"
movies = soup.find_all('div', class_='lister-item mode-advanced')

# %%
# For each movie, extract the title and rating
movie_name = []
Rating = []
for movie in movies:
    
    title = movie.h3.a.text
    movie_name.append(title)

    rating = movie.strong.text
    Rating.append(rating)

# %%
# we will create a dictionary first, then turn this dictionary to the DataFrame, and see the top 5 elements of it.
dic = {"Movie Name" : movie_name, "Rating" : Rating}
df = pd.DataFrame(dic)
df.head(5)
# Out:
#                  Movie Name Rating
# 0  The Shawshank Redemption    9.3
# 1             The Godfather    9.2
# 2           The Dark Knight    9.0
# 3          Schindler's List    9.0
# 4     The Godfather Part II    9.0

# %%
# we will repeat the process once again, but this time we will use another link because the link of the 51-100 is different.
movie_name_2 = []
Rating_2 = []

movie_name_2 = []
Rating_2 = []

import requests
from bs4 import BeautifulSoup

# Send an HTTP request to the URL of the webpage you want to access
url = "https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc&start=51&ref_=adv_nxt"
page = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(page.text, 'html.parser')

# Find all the <div> elements with the class "lister-item mode-advanced"
movies = soup.find_all('div', class_='lister-item mode-advanced')

# For each movie, extract the title and rating
for movie in movies:
    
    title = movie.h3.a.text
    movie_name_2.append(title)

    rating = movie.strong.text
    Rating_2.append(rating)

dic2 = {"Movie Name" : movie_name_2, "Rating" : Rating_2}
df2 = pd.DataFrame(dic2)
df2.head(5)
# Out:
#                           Movie Name Rating
# 0                       Modern Times    8.5
# 1                        City Lights    8.5
# 2                  Avengers: Endgame    8.4
# 3  Spider-Man: Into the Spider-Verse    8.4
# 4             Avengers: Infinity War    8.4

# %%
# In the final step, we will merge two DataFrames, and here we have IMDB's top 100 movie list.
imdb_top_100 =  pd.concat([df, df2], axis=0)
pd.set_option('display.max_rows', None)
imdb_top_100
# Out:
#                                            Movie Name Rating
# 0                            The Shawshank Redemption    9.3
# 1                                       The Godfather    9.2
# 2                                     The Dark Knight    9.0
# 3                                    Schindler's List    9.0
# 4                               The Godfather Part II    9.0
# 5                                        12 Angry Men    9.0
# 6       The Lord of the Rings: The Return of the King    9.0
# 7                                        Pulp Fiction    8.9
# 8                                           Inception    8.8
# 9   The Lord of the Rings: The Fellowship of the Ring    8.8
# 10                                         Fight Club    8.8
# 11                                       Forrest Gump    8.8
# 12                     The Good, the Bad and the Ugly    8.8
# 13              The Lord of the Rings: The Two Towers    8.8
# 14                                         Goodfellas    8.7
# 15                                         The Matrix    8.7
# 16                    One Flew Over the Cuckoo's Nest    8.7
# 17     Star Wars: Episode V - The Empire Strikes Back    8.7
# 18                                       Interstellar    8.6
# 19                                     The Green Mile    8.6
# 20                 Star Wars: Episode IV - A New Hope    8.6
# 21                                              Se7en    8.6
# 22                           The Silence of the Lambs    8.6
# 23                                Saving Private Ryan    8.6
# 24                                      Spirited Away    8.6
# 25                                        City of God    8.6
# 26                         Terminator 2: Judgment Day    8.6
# 27                                  Life Is Beautiful    8.6
# 28                                      Seven Samurai    8.6
# 29                              It's a Wonderful Life    8.6
# 30                                           Harakiri    8.6
# 31                             Léon: The Professional    8.5
# 32                                           Parasite    8.5
# 33                                       The Departed    8.5
# 34                                          Gladiator    8.5
# 35                                           Whiplash    8.5
# 36                                 Back to the Future    8.5
# 37                                              Alien    8.5
# 38                                       The Prestige    8.5
# 39                                      The Lion King    8.5
# 40                                 The Usual Suspects    8.5
# 41                                             Psycho    8.5
# 42                                        The Pianist    8.5
# 43                                 American History X    8.5
# 44                                   The Intouchables    8.5
# 45                                         Casablanca    8.5
# 46                       Once Upon a Time in the West    8.5
# 47                             Grave of the Fireflies    8.5
# 48                                        Rear Window    8.5
# 49                                    Cinema Paradiso    8.5
# 0                                        Modern Times    8.5
# 1                                         City Lights    8.5
# 2                                   Avengers: Endgame    8.4
# 3                   Spider-Man: Into the Spider-Verse    8.4
# 4                              Avengers: Infinity War    8.4
# 5                                               Joker    8.4
# 6                                              Oldboy    8.4
# 7                                    Django Unchained    8.4
# 8       Indiana Jones and the Raiders of the Lost Ark    8.4
# 9                                      Apocalypse Now    8.4
# 10                                        The Shining    8.4
# 11                                       Come and See    8.4
# 12                              The Dark Knight Rises    8.4
# 13                                             Aliens    8.4
# 14                                            Memento    8.4
# 15                                         Your Name.    8.4
# 16                                          Capernaum    8.4
# 17                                         Braveheart    8.4
# 18                                               Coco    8.4
# 19                                             WALL·E    8.4
# 20                                            Amadeus    8.4
# 21                                The Lives of Others    8.4
# 22  Dr. Strangelove or: How I Learned to Stop Worr...    8.4
# 23                                       Sunset Blvd.    8.4
# 24                                           Das Boot    8.4
# 25                                           3 Idiots    8.4
# 26                                     Paths of Glory    8.4
# 27                        Witness for the Prosecution    8.4
# 28                                 The Great Dictator    8.4
# 29                                       High and Low    8.4
# 30                                  Good Will Hunting    8.3
# 31                               Inglourious Basterds    8.3
# 32         Star Wars: Episode VI - Return of the Jedi    8.3
# 33                                Requiem for a Dream    8.3
# 34                                    American Beauty    8.3
# 35              Eternal Sunshine of the Spotless Mind    8.3
# 36                              2001: A Space Odyssey    8.3
# 37                                     Reservoir Dogs    8.3
# 38                                           The Hunt    8.3
# 39                        Once Upon a Time in America    8.3
# 40                                          Toy Story    8.3
# 41                                Singin' in the Rain    8.3
# 42                                 Lawrence of Arabia    8.3
# 43                                       Citizen Kane    8.3
# 44                                  Princess Mononoke    8.3
# 45                                        Toy Story 3    8.3
# 46                                 North by Northwest    8.3
# 47                                                  M    8.3
# 48                                              Ikiru    8.3
# 49                                      The Apartment    8.3
